# %% [markdown]
# <a href="https://colab.research.google.com/github/SaniyaIrfan1113/MachineLearningProjects/blob/main/01_Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-1355faef-652f-4e59-8808-e18d7d96f341" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1355faef-652f-4e59-8808-e18d7d96f341">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset = pd.read_csv("studentscores.csv")

# %%
dataset.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
dataset.shape
# Out:
# (25, 2)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 532.0 bytes

# %%
dataset.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    test_size=0.25,
    random_state=0
)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (18, 1)
# (7, 1)

# %%
model = LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
comparison = pd.DataFrame({
    "Actual":Y_test,
    "Predicted":Y_pred
})

comparison
# Out:
#    Actual  Predicted
# 0      20  16.844722
# 1      27  33.745575
# 2      69  75.500624
# 3      30  26.786400
# 4      62  60.588106
# 5      35  39.710582
# 6      24  20.821393

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
print("MAE :",mean_absolute_error(Y_test,Y_pred))

print("MSE :",mean_squared_error(Y_test,Y_pred))

print("R2 Score :",r2_score(Y_test,Y_pred))
# Out:
# MAE : 4.130879918502482
# MSE : 20.33292367497996
# R2 Score : 0.9367661043365056

# %%
plt.scatter(X_train,Y_train,color="blue")

plt.plot(
    X_train,
    model.predict(X_train),
    color="red"
)

plt.title("Training Set")

plt.xlabel("Hours Studied")

plt.ylabel("Score")

plt.show()

# %%
plt.scatter(X_test,Y_test,color="green")

plt.plot(
    X_train,
    model.predict(X_train),
    color="red"
)

plt.title("Testing Set")

plt.xlabel("Hours Studied")

plt.ylabel("Score")

plt.show()

# %%
model.predict([[9.5]])
# Out:
# array([96.37814848])

# %%
print(model.coef_)
# Out:
# [9.94167834]

# %%
print(model.intercept_)
# Out:
# 1.9322042531516601

# %%
import joblib

joblib.dump(model,"student_score_model.pkl")
# Out:
# ['student_score_model.pkl']

# %% [markdown]
# 01_Simple_Linear_Regression.ipynb
#
# 1. Import Libraries
# 2. Upload Dataset
# 3. Read Dataset
# 4. Explore Dataset
# 5. Split Data
# 6. Train Model
# 7. Prediction
# 8. Evaluation
# 9. Visualization
# 10. Predict New Data
# 11. Save Model
